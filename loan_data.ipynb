# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('data.csv')
# Out:
# C:\Users\prasa\AppData\Local\Temp\ipykernel_13476\2471439888.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('data.csv')

# %%
data.head()
# Out:
#                                              Picture                Website  \
# 0  https://xubs-akpz-sxip.n7.xano.io/vault/TEisAJ...         www.fjlabs.com
# 1  https://xubs-akpz-sxip.n7.xano.io/vault/JXk4kD...                    NaN
# 2  https://xubs-akpz-sxip.n7.xano.io/vault/TEisAJ...  www.indexventures.com
# 3  https://xubs-akpz-sxip.n7.xano.io/vault/TEisAJ...           www.a16z.com
# 4  https://xubs-akpz-sxip.n7.xano.io/vault/JXk4kD...               shine.vc
#
#             City      County        Country    Organization Name  \
# 0       New York    New York  United States              FJ Labs
# 1      San Mateo  California  United States                  NaN
# 2  San Francisco  California  United States       Index Ventures
# 3     Menlo Park  California  United States  Andreessen Horowitz
# 4       New York    New York  United States                  NaN
#
#   Individual Name              Role       Name of Firm  \
# 0             NaN      Organization                NaN
# ...

# %%
data.describe()
# Out:
#                                                   Picture  \
# count                                               35683
# unique                                              22652
# top     https://xubs-akpz-sxip.n7.xano.io/vault/TEisAJ...
# freq                                                    7
#
#                     Website      City      County        Country  \
# count                 90274    123601      101031         147777
# unique                31676      4817         909            171
# top     www.harbourvest.com  New York  California  United States
# freq                    276     11444       17410          62483
#
#        Organization Name Individual Name            Role  \
# count              46194          102995          149189
# unique             28937           63549              20
# top        Eight Capital     Brian Kelly  Angel Investor
# freq                   9              13           57679
#
#                 Name of Firm  \
# ...

# %%
data.head(15)
# Out:
#                                               Picture                 Website  \
# 0   https://xubs-akpz-sxip.n7.xano.io/vault/TEisAJ...          www.fjlabs.com
# 1   https://xubs-akpz-sxip.n7.xano.io/vault/JXk4kD...                     NaN
# 2   https://xubs-akpz-sxip.n7.xano.io/vault/TEisAJ...   www.indexventures.com
# 3   https://xubs-akpz-sxip.n7.xano.io/vault/TEisAJ...            www.a16z.com
# 4   https://xubs-akpz-sxip.n7.xano.io/vault/JXk4kD...                shine.vc
# 5   https://xubs-akpz-sxip.n7.xano.io/vault/TEisAJ...    www.mesoncapital.com
# 6   https://xubs-akpz-sxip.n7.xano.io/vault/TEisAJ...       www.artsfund.org/
# 7   https://xubs-akpz-sxip.n7.xano.io/vault/JXk4kD...      www.clear-sky.com/
# 8   https://xubs-akpz-sxip.n7.xano.io/vault/TEisAJ...     venturecatalysts.in
# 9   https://xubs-akpz-sxip.n7.xano.io/vault/JXk4kD...        january.ventures
# 10  https://xubs-akpz-sxip.n7.xano.io/vault/TEisAJ...             www.8vc.com
# ...

# %%
data.head()
# Out:
#                                              Picture                Website  \
# 0  https://xubs-akpz-sxip.n7.xano.io/vault/TEisAJ...         www.fjlabs.com
# 1  https://xubs-akpz-sxip.n7.xano.io/vault/JXk4kD...                    NaN
# 2  https://xubs-akpz-sxip.n7.xano.io/vault/TEisAJ...  www.indexventures.com
# 3  https://xubs-akpz-sxip.n7.xano.io/vault/TEisAJ...           www.a16z.com
# 4  https://xubs-akpz-sxip.n7.xano.io/vault/JXk4kD...               shine.vc
#
#             City      County        Country    Organization Name  \
# 0       New York    New York  United States              FJ Labs
# 1      San Mateo  California  United States                  NaN
# 2  San Francisco  California  United States       Index Ventures
# 3     Menlo Park  California  United States  Andreessen Horowitz
# 4       New York    New York  United States                  NaN
#
#   Individual Name              Role       Name of Firm  \
# 0             NaN      Organization                NaN
# ...

# %%
copy_data = data.copy(deep=True)

# %%
copy_data.dropna(inplace=True, subset=['Individual Name'])

# %%
copy_data.head()
# Out:
#                                               Picture              Website  \
# 1   https://xubs-akpz-sxip.n7.xano.io/vault/JXk4kD...                  NaN
# 4   https://xubs-akpz-sxip.n7.xano.io/vault/JXk4kD...             shine.vc
# 7   https://xubs-akpz-sxip.n7.xano.io/vault/JXk4kD...   www.clear-sky.com/
# 9   https://xubs-akpz-sxip.n7.xano.io/vault/JXk4kD...     january.ventures
# 12  https://xubs-akpz-sxip.n7.xano.io/vault/JXk4kD...  www.initialized.com
#
#                 City         County        Country Organization Name  \
# 1          San Mateo     California  United States               NaN
# 4           New York       New York  United States               NaN
# 7   North Palm Beach        Florida  United States               NaN
# 9             Boston  Massachusetts  United States               NaN
# 12     San Francisco     California  United States               NaN
#
#                Individual Name              Role         Name of Firm  \
# ...

# %%
copy_data.describe()
# Out:
#                                                   Picture  \
# count                                                6170
# unique                                               3977
# top     https://xubs-akpz-sxip.n7.xano.io/vault/TEisAJ...
# freq                                                    6
#
#                     Website      City      County        Country  \
# count                 51830     80980       58187         101583
# unique                13022      3102         690            163
# top     www.harbourvest.com  New York  California  United States
# freq                    274      8601       12957          45968
#
#        Organization Name Individual Name            Role  \
# count                  0          102995          102995
# unique                 0           63549              19
# top                  NaN     Brian Kelly  Angel Investor
# freq                 NaN              13           57679
#
#                 Name of Firm  \
# ...

# %%
us_data =copy_data[copy_data['Country']=='United States']

# %%
us_data.to_csv('output.csv', index=False)
